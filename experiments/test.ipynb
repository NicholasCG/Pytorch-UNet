# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
test_mask = Image.open('../data/masks/img1_glare4_mask.png')
glare_original = Image.open('../data/imgs/img1_glare4.png')
clean_original = Image.open('../data/orig/img1.png')

# %%
display(test_mask)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x522 at 0x7FF2D17B6430>

# %%
plt.figure(figsize=(20, 20))
test = np.array(glare_original) - np.array(clean_original)
plt.imshow(test)

# %%
print(test.max())
print(test.min())

# %%
display(glare_original)
display(clean_original)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x522 at 0x7FF30C744220>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x522 at 0x7FF2CDA6F250>

# %%
plt.figure(figsize=(20, 20))
plt.imshow(np.array(glare_original) - np.array(test_mask))
